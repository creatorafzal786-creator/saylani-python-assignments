# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
# Write your code here
name = "afzal ahmad"
print(name.upper())
# Out:
# AFZAL AHMAD

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
# Write your code here

fav = input("Enter Your Favourite Fruit: ")
print(len(fav))
# Out:
# Enter Your Favourite Fruit:  mango
# 5

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
# Write your code here
a = "Python is fun" 
b = a.replace('fun', 'awesome' )
print(b)
# Out:
# Python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
# Write your code here

a = "Hello World"
b = a.index('World')
print(b)
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
# Write your code here
a = input("Enter Your Email: ")
print(a.lower())
# Out:
# Enter Your Email:  AFZAL@GMAIL.COM
# afzal@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
# Write your code here

a = ' Python Programming '
b = a.strip()
print(b)
# Out:
# Python Programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
# Write your code here

convert = 'Welcome to coding'
find_1 = convert.count("o")
print(find_1)
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
# Write your code here
age = input("Enter Your Age: ")
age_1 = int(age)

print(age_1)
# Out:
# Enter Your Age:  9

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
# Write your code here
value = 15.99
value_1 = int(value)
print(value_1)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
# Write your code here
a = input("Enter The Number: ")
b = input("Enter The Number: ")
c = int(a) + int(b)
print(c)
# Out:
# Enter The Number:  99
# Enter The Number:  08
# 107

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
# Write your code here
a = 100
b = str(a)
print(b)
# Out:
# 100

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
# Write your code here
user = float(input("Enter The Number: "))
b = int(user)
print(b)
# Out:
# Enter The Number:  99.5
# 99

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
# Write your code here
s1 = "10"
s2 = "20"

result = int(s1) + int(s2)

print(result)
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
# Write your code here

var = '50.5'
num = float(var)
results = num + 10
print(results)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
# Write your code here
name = input("Enter Your Name: ")
city = input("Enter Your city: ")

print(f"Hello {name}, welcome to {city}")
# Out:
# Enter Your Name:  Afzal Ahmad
# Enter Your city:  Chilas
# Hello Afzal Ahmad, welcome to Chilas

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
# Write your code here
num1 = float(input("Enter the 1st Number: "))
num2 = float(input("Enter the 2st Number: "))

results = num1 * num2
print(results)
# Out:
# Enter the 1st Number:  3
# Enter the 2st Number:  3
# 9.0

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
# Write your code here
color = input("Enter Your Favourite Color: ")
print(f"I also like {color}")
# Out:
# Enter Your Favourite Color:  black
#  I also like black

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
# Write your code here
year = int(input("Enter The Year You Born: "))
current_year = int(input("Enter Current Year: "))
age = current_year - year

print(age)
# Out:
# Enter The Year You Born:  46643
# Enter Current Year:  4432
# -42211

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
# Write your code here

user = input("Enter SoME Thing: ")
word = user * 5
print(word)
# Out:
# Enter SoME Thing:  hello
# hellohellohellohellohello

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
# Write your code here
user = input('Enter Your Mobile Number: ')
num = (f"You Entered This Number: {user}")
# Out:
# Enter Your Mobile Number:  03131689935

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
# Write your code here
a = 10
b = 3
results = a % b
print(results)
# Out:
# 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
# Write your code here
num = 15

if num > 10 and num < 20:
    print("Both conditions are True")
else:
    print("Condition is False")
# Out:
# Both conditions are True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
# Write your code here
user = int(input("Enter The Number: "))
if user > 100:
    print("Number is greater than 100")
else:
    print("Number is not greater than 100")
# Out:
# Enter The Number:  1333
# Number is greater than 100

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
# Write your code here
result = 2**5
print(result)
# Out:
# 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
# Write your code here

num = 50

if num == 100:
    print("Equal")
else:
    print("Not Equal")
# Out:
# Not Equal

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
# Write your code here
a = True
b = False

result = a or b
print(result)
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
# Write your code here
user = int(input("Enter The Number: "))

if user > 0:
    print("Positive Number")
elif user < 0:
    print("Negative Number")
else:
    print("Number is Zero")
# Out:
# Enter The Number:  0
# Number is Zero

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
# Write your code here
age = int(input("Enter Your Age: "))

if age >= 18:
    print("Eligible for Vote")
else:
    print("Not Eligible")
# Out:
# Enter Your Age:  19
# Eligible for Vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
# Write your code here
num = int(input("Enter THE number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter THE number:  4
# Even

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
# Write your code here
num1 = int(input("Enter THE 1st number: "))
num2 = int(input("Enter THE 2nd number: "))

if num1 > num2:
    print("1st Number Is Greater")
elif num2 > num1:
    print("2nd Number Is Greater")
else:
    print("Both numbers are equal")
# Out:
# Enter THE 1st number:  2
# Enter THE 2nd number:  4
# 2nd Number Is Greater

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
# Write your code here
marks = int(input("Enter Your Marks: "))
if marks > 33:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Your Marks:  41
# Pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
# Write your code here
text = input("Enter Something: ")
if text == "":
    print("String is Empty")
else:
    print("String is Not Empty")
# Out:
# Enter Something:
# String is Empty

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
# Write your code here
user = input("Enter Your Password:")
if user == "python123":
    print("Access Granted")

else:
    print("Wrong Password")
# Out:
# Enter Your Password: python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# Write your code here
user = int(input("Enter The Number: "))

if user == 0:
     print("Number is Zero")
else:
    print("Number is Not Zero")
# Out:
# Enter The Number:  0
# Number is Zero

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
# Write your code here
marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 80:
    print("Grade: B")
elif marks >= 70:
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# Enter your marks:  99
# Grade: A

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temp = float(input("Enter The Temoerature: "))
if temp >=30:
    print("Hot")

elif temp >= 15:
    print("Warm")

else:
    print("Cold")
# Out:
# Enter The Temoerature:  13
# Cold

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here
num = int(input("Enter The Number: "))
if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz") 

elif num % 3 == 0:
    print("Fizz")      
elif num % 5 == 0:
    print("Buzz")     
else:
    print(num)
# Out:
# Enter The Number:  15
# FizzBuzz

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code here
char = input("Enter Any Vowel: ")
if char in "aeiou":
    print("Vowel")

else:
    print("Consonant")
# Out:
# Enter Any Vowel:  n
# Consonant

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
bill = int(input("Enter Shopping Bill Here: "))
if bill >= 5000:
    discount = 5000 * .20
elif bill >= 2000:
    discount = 2000*.10

else:
   no_discount = 0

final_bill = bill - discount
print(f"Discount {discount} and Final Bill is {final_bill} and No discount")
# Out:
# Enter Shopping Bill Here:  2
# Discount 0 and Final Bill is 2 and No discount0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("Enter Age Here: "))
if age <= 12:
    print("Child")
elif age <= 19:
    print("Teenager")

elif age <= 59:
    print("Adult")
elif age >=60:
    print("Senior Citizen")
else:
    print("Invalid")
# Out:
# Enter Age Here:  99
# Senior Citizen

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here
year = int(input("Saal daal bhai: "))

if year % 400 == 0:
    print(f"{year} Leap Year hai")
elif year % 100 == 0:
    print(f"{year} Leap Year nahi hai")
elif year % 4 == 0:
    print(f"{year} Leap Year hai")
else:
    print(f"{year} Leap Year nahi hai")
# Out:
# Saal daal bhai:  2024
# 2024 Leap Year hai

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here

day = int(input("Week number daal bhai 1-7: "))

if day == 1:
    day_name = "Monday"
elif day == 2:
    day_name = "Tuesday"
elif day == 3:
    day_name = "Wednesday"
elif day == 4:
    day_name = "Thursday"
elif day == 5:
    day_name = "Friday"
elif day == 6:
    day_name = "Saturday"
elif day == 7:
    day_name = "Sunday"
else:
    day_name = "Invalid Day Number"

print(day_name)
# Out:
# Week number daal bhai 1-7:  6
# Saturday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# Write your code here
num1 = int(input("Enter first number: "))
op = input("Enter operator (+, -, *, /): ")
num2 = int(input("Enter second number: "))

if op == "+":
    print(num1 + num2)
elif op == "-":
    print(num1 - num2)
elif op == "*":
    print(num1 * num2)
elif op == "/":
    print(num1 / num2)
# Out:
# Enter first number:  22
# Enter operator (+, -, *, /):  +
# Enter second number:  2
# 24

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float(input("Enter Your Weight(kg): "))
height = float(input("Enter Your Height(meters): "))

bmi = weight / (height**2)

if bmi >= 18.5:
    print("underweight")

elif bmi < 25:
    print("Normal")
else:
    print("Overweight")
# Out:
# Enter Your Weight(kg):  321
# Enter Your Height(meters):  32
# Normal

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
# Write your code here
balance = 5000
pin = int(input("Enter Your Pin: "))
if pin == 1234:
    ammount = int(input("Enter The Ammount: "))
    if ammount <= balance:
        print("Withdrawal Success")
    else:
        print("Insufficient Balance")
else:
    print("Wrong Pin")
# Out:
# Enter Your Pin:  1234
# Enter The Ammount:  50005
# Insufficient Balance

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
# Write your code here
user = input("Enter Username: ")
if user == "afzal":
    password = input("Enter Password: ")
    if password == "1234":
        print("Correct Password")
        if user == password:
         print("Login Successful")
    else:
        print("Incorrect")
    print("Username Correct")
else:
    print("Incorrect Username")
# Out:
# Enter Username:  12345
# Incorrect Username

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b:
    if a > c:
        print("a")
    else:
        print("c")
else:
    if b > c:
        print("b")
    else:
        print("c")
# Out:
# Enter first number:  23
# Enter second number:  55
# Enter third number:  77
# c

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
# Write your code here
age = int(input(Enter Your Age: ))
if age >= 18:
    card = input("Do you have ID? (yes/no): ")
    if card == "yes":
        print("Ticket Issued")
    els
    


    
    print("ID Issued")
else:
    print("Not Eligible")

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
student = int(input("Enter Your Marks: "))
if student >= 80:
    print("Marks criteria passed")
    interview = input("Interview cleared? (yes/no): ")
    if interview == "yes":
        print("Admission Done")

    else:
        print("Interview not cleared")

else:
    print("Marks too low")
# Out:
# Enter Your Marks:  66
# Marks too low

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
num = int(input("Enter The Number: "))
if num >= 0:
    print("Number is Positive")
    if num >= 100:
        print("Number Is Greater Then 100")
    else:
        print("Less Than 100")
else:
    print("Number Is Negative")
# Out:
# Enter The Number:  101
# Number is Positive
# Number Is Greater Then 100

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
# Write your code here

choice = input("Veg or Non-Veg: ").lower()

if choice == "veg":
    item = input("Paneer ya Dal: ").lower()

    if item == "paneer":
        print("You ordered Paneer")

    elif item == "dal":
        print("You ordered Dal")

    else:
        print("Invalid Order")

elif choice == "non veg":
    item = input("Chicken or Mutton? ").lower()

    if item == "chicken":
        print("You ordered Chicken")

    elif item == "mutton":
        print("You ordered Mutton")

    else:
        print("Invalid Choice")

else:
    print("Invalid Choice")
# Out:
# Veg or Non-Veg:  ;
# Invalid Choice

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
num = input("Enter Any Number: ")
if len(num) == 1:
    print("Single Digit")

elif len(num) == 2:
    print("Double Digit")
elif len(num) == 3:
    print("Tripile Digit")
else:
    print("More Than 3 Digit")
# Out:
# Enter Any Number:  333
# Tripile Digit

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
salary = int(input("Enter Your Salary: "))
service = int(input("Enter Your Service Years: "))
if service > 5:
    bonus = salary * 5/100
    final = salary + bonus
else:
    final = salary
print(final)
# Out:
# Enter Your Salary:  50000
# Enter Your Service Years:  2
# 50000

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
# Write your code here
side1 = int(input("Enter 1st Side: "))
side2 = int(input("Enter 2nd Side: "))
side3 = int(input("Enter 3rd Side: "))

if side1 == side2 == side3:
    print("Triangle is Equilateral")
elif side1 == side2 or side2 == side3 or side1 == side3:
    print("Triangle Is Isosceles")
else:
    print("Triangle is Scalene")
# Out:
# Enter 1st Side:  5
# Enter 2nd Side:  4
# Enter 3rd Side:  5
# Triangle Is Isosceles

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
# Write your code here
month = input("Enter Month Name: ")
if month in ["january", "march", "may", "july", "august", "october", "december"]:
    print("31 Days")
elif month in ["april", "june", "september", "november"]:
    print("30 Days")
elif month == "february":
    print("28 or 29 Days (Leap Year)")
else:
    print("Invalid Months Name")
# Out:
# Enter Month Name:  january
# 31 Days

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here
num = int(input("Enter The Number: "))
if num % 2 == 0:
    print("Numer Is Even")
    if num > 50:
        print("Number Is Greater Than 50")
    else:
        print("Number Is Less Than or Equal to 50")
else:
    print("Number is Odd")
# Out:
# Enter The Number:  70
# Numer Is Even
# Number Is Greater Than 50

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

if maths >= 40:
    
    if science >= 40:
        print("Pass")
    else:
        print("Weak in Science")

else:
    
    if science >= 40:
        print("Weak in Maths")
    else:
        print("Weak in Maths and Science")

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
units = int(input("Enter electricity units: "))

if units <= 100:
    bill = 0

elif units <= 200:
    bill = (units - 100) * 5

else:
    bill = (100 * 5) + ((units - 200) * 10)

print("Electricity Bill:", bill)

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
score = int(input("Enter Your game level: "))
if score <= 50:
    print("Beginner")
elif score <= 100:
    print("Intermediate")
    boss = input("Boss level complete? (yes/no): ").lower()
    
    if boss == "yes":
        print("Boss Level Cleared")
    else:
        print("Boss Level Not Cleared")

else:
    print("Invalid Score")

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
username = "admin"
password = "python123"
security_answer = "blue"

user = input("Enter Username: ")

if user == username:
    
    pwd = input("Enter Password: ")
    
    if pwd == password:
        
        answer = input("What is your favourite color? ").lower()
        
        if answer == security_answer:
            print("Login Successful")
        else:
            print("Wrong Security Answer")
    
    else:
        print("Wrong Password")

else:
    print("Wrong Username")
